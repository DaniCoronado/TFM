# %% [markdown]
# # Usaremos el output del modelo LSTM como características input del Árbol de Decisión
#
# ![LSTM TREE.png](attachment:e63406eb-7445-4aed-8bbc-7f668af092bc.png)

# %%
import pandas as pd

df_audio_features = pd.read_csv('/kaggle/input/5ms-upgrade/5MS_audio_features.csv', index_col=0)
df_5MS = pd.read_csv('/kaggle/input/5ms-upgrade/final_5MS.csv', index_col=0)

# %%
df_audio_features = df_audio_features.merge(df_5MS, how='right', right_on='id', left_on='id')[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'tag', 'id']]
df_audio_features
# Out:
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0              0.485   0.710   7.0    -6.288   1.0       0.3640        0.0444
# 1              0.828   0.654  10.0    -8.348   0.0       0.0784        0.1520
# 2              0.889   0.818   9.0    -4.639   1.0       0.2530        0.4700
# 3              0.612   0.850   1.0    -4.703   1.0       0.5000        0.0393
# 4              0.792   0.694   8.0    -8.496   0.0       0.3300        0.0619
# ...              ...     ...   ...       ...   ...          ...           ...
# 302213         0.417   0.327   7.0   -12.678   1.0       0.0321        0.6530
# 302214         0.309   0.871   5.0    -3.556   1.0       0.0867        0.0972
# 302215         0.632   0.188  11.0   -13.764   0.0       0.0364        0.6640
# 302216         0.352   0.790   2.0    -2.915   1.0       0.0319        0.0719
# 302217         0.407   0.523   0.0    -6.431   1.0       0.0331        0.4540
#
#         instrumentalness  liveness  valence    tempo  duration_ms      tag  \
# 0               0.000000    0.3500    0.473  170.942     316267.0      rap
# 1               0.000000    0.0563    0.862   93.007     247827.0      rap
# 2               0.000000    0.1790    0.782   96.063     302760.0      rap
# 3               0.000000    0.2550    0.781  173.497     204027.0      rap
# 4               0.000023    0.2500    0.804  177.094     309773.0      rap
# ...                  ...       ...      ...      ...          ...      ...
# 302213          0.608000    0.2290    0.394   84.681     167400.0       rb
# 302214          0.000000    0.1970    0.550   84.574     191478.0  country
# 302215          0.002970    0.4810    0.573   88.876     123200.0       rb
# 302216          0.000000    0.0714    0.320   74.973     200000.0      pop
# 302217          0.000000    0.0874    0.336  138.958     166427.0  country
#
#                             id
# 0       2tQM1BUrXp2kqOM6mN11TC
# 1       04kvMnJ6zo72bSnZDWyE7m
# 2       5ByAIlEEnxYdvpnezg7HTX
# 3       1Z7C8ClE8UEaH70jCCeJH2
# 4       4LGMSdeKOUoy5Wf75Je0Hl
# ...                        ...
# 302213  29EAgZQVXMQwm2O81MffjV
# 302214  46XuJOFMgB1biZv3rztHpT
# 302215  6yItLFQtv1NVafUWSkmE2S
# 302216  2bVh1aGyCWxKkZvEn61xZ1
# 302217  6xboopPn3bSJ93xZ9N6BZM
#
# [302218 rows x 14 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

df_audio_features['tag']= label_encoder.fit_transform(df_audio_features['tag'])
label_encoder.classes_
# Out:
# array(['country', 'misc', 'pop', 'rap', 'rb', 'rock'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df_audio_features[columns], df_audio_features.tag, test_size=0.2, random_state=1)

print(f"Training data samples: {len(x_train)}")
print(f"Test data samples: {len(x_test)}")
# Out:
# Training data samples: 241774
# Test data samples: 60444

# %% [markdown]
# # TO DO: AGREGAR LA SALIDA DE LSTM COMO COLUMNAS DE AUDIO FEATURES

# %%
lstm_train_preds = pd.read_csv("/kaggle/input/lstm-results/predicts_vs_real_TRAIN.csv", index_col=0)
print('Train checker:', all(y_train.values == lstm_train_preds.tag.values))
lstm_train_preds.drop(columns='tag', inplace=True)

lstm_test_preds = pd.read_csv("/kaggle/input/lstm-results/predicts_vs_real_TEST.csv", index_col=0)
print('Test checker:', all(y_test.values == lstm_test_preds.tag.values))
lstm_test_preds.drop(columns='tag', inplace=True)
# Out:
# Train checker: True
# Test checker: True

# %%
x_train = pd.concat([x_train, lstm_train_preds.set_index(x_train.index)], axis=1)
x_test = pd.concat([x_test, lstm_test_preds.set_index(x_test.index)], axis=1)

# %% [markdown]
# # TO DO: CONSTRUCCION DE UN MODELO
# 1. pipeline de preprocesamiento
# 2. modelo

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

transformer = Pipeline([('imputer', SimpleImputer()), ('scaler', StandardScaler())])
transformer
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())])

# %%
import numpy as np
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

dt_model = tree.DecisionTreeClassifier();
churn_pipe_tree = Pipeline(steps=[('prep', transformer), ('clas', dt_model)])

churn_pipe_tree.fit(x_train, y_train)
print('Accuracy sin ajuste de hiperparámetros:', churn_pipe_tree.score(x_test, y_test))

parameters = {}
parameters['prep__imputer__strategy'] = ['mean', 'median']
parameters['clas__max_depth'] = [None, 3, 5, 7, 9]
parameters['clas__class_weight'] = [None, 'balanced']

GS = GridSearchCV(churn_pipe_tree, parameters, scoring='accuracy')
GS.fit(x_train, y_train)

churn_pipe_tree = GS.best_estimator_

pred_probs = churn_pipe_tree.predict_proba(x_test)
y_test_pred = np.argmax(pred_probs, axis=1)
report = classification_report(y_test, y_test_pred, output_dict=True)

print('\nTras el ajuste de hiperparámetros:')
pd.DataFrame(report).T
# Out:
# Accuracy sin ajuste de hiperparámetros: 0.4821487657997485
#
# Tras el ajuste de hiperparámetros:
#               precision    recall  f1-score       support
# 0              0.590518  0.792050  0.676596  14138.000000
# 1              0.717199  0.238362  0.357806   3394.000000
# 2              0.372290  0.158673  0.222510  11905.000000
# 3              0.710851  0.727187  0.718926   7441.000000
# 4              0.455955  0.636243  0.531219  10584.000000
# 5              0.595519  0.591665  0.593586  12982.000000
# accuracy       0.557905  0.557905  0.557905      0.557905
# macro avg      0.573722  0.524030  0.516774  60444.000000
# weighted avg   0.546975  0.557905  0.531186  60444.000000

# %% [markdown]
# Obtenemos una mejora del **~5%** en el clasificador final

# %% [markdown]
# `En los casos de las clases más problemáticas (1: 'misc', 2: 'pop'), el clasificador obtiene mucha mayor precision que recall. El clasificador tiende a etiquetar una nueva canción como Misc o Pop solamente cuando está completamente seguro de hacerlo. Por ello, siempre que predice alguno de estos dos géneros tiende a acertar (precision alta). Sin embargo, esta misma lógica suele llevarle al error; haciéndole que se le escapen otras muchas canciones Misc o Pop (recall bajo).`
